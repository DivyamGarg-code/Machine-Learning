# %%
import pandas as pd

# %% [markdown]
# # Iris data

# %%
data=pd.read_csv('iris.csv')

# %%
df=data.copy()
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
l=set(list(df.variety))
for i in l:
    cnt=df.variety[df.variety==i].count()
    print(cnt,end=" ")
# Out:
# 50 50 50

# %%
df.columns=['sl','sw','pl','pw','variety']
df=df[df.variety=='Virginica']
df[df.pl>6]
# Out:
#       sl   sw   pl   pw    variety
# 105  7.6  3.0  6.6  2.1  Virginica
# 107  7.3  2.9  6.3  1.8  Virginica
# 109  7.2  3.6  6.1  2.5  Virginica
# 117  7.7  3.8  6.7  2.2  Virginica
# 118  7.7  2.6  6.9  2.3  Virginica
# 122  7.7  2.8  6.7  2.0  Virginica
# 130  7.4  2.8  6.1  1.9  Virginica
# 131  7.9  3.8  6.4  2.0  Virginica
# 135  7.7  3.0  6.1  2.3  Virginica

# %%
df=data.copy()
df.columns=['sl','sw','pl','pw','variety']
l=list(set(list(df.variety)))
l.sort()
print(l)
for i in l:
    print(i)
    a=df[df.variety==i]
    print(a.sl.min(),a.sw.min(),a.pl.min(),a.pw.min())
    print(a.sl.max(),a.sw.max(),a.pl.max(),a.pw.max())
    print(a.sl.mean().round(2),a.sw.mean().round(2),a.pl.mean().round(2),a.pw.mean().round(2))
# Out:
# ['Setosa', 'Versicolor', 'Virginica']
# Setosa
# 4.3 2.3 1.0 0.1
# 5.8 4.4 1.9 0.6
# 5.01 3.43 1.46 0.25
# Versicolor
# 4.9 2.0 3.0 1.0
# 7.0 3.4 5.1 1.8
# 5.94 2.77 4.26 1.33
# Virginica
# 4.9 2.2 4.5 1.4
# 7.9 3.8 6.9 2.5
# 6.59 2.97 5.55 2.03

# %% [markdown]
# # Terrorism Data

# %%
d=pd.read_csv('terrorismData.csv')
df=d.copy()
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
# which city in Jammu and Kashmir has the maximum attacks
a=df[df.State=='Jammu and Kashmir']
l=list(a.City)
d={}
for i in l:
    if i not in d.keys():
        d[i]=1;
    else:
        d[i]+=1;
d_v=list(d.values())
d_k=list(d.keys())
max_attacks=max(d_v)
dan_place=d_k[d_v.index(max_attacks)]
print(f"most dangerous place--> '{dan_place}' with the maximum number of attacks --> {max_attacks}")
# Out:
# most dangerous place--> 'Srinagar' with the maximum number of attacks --> 657

# %%
# country with the maximum number of terror attacks
l=list(df.Country)
d={}
for i in l:
    if i not in d.keys():
        d[i]=1;
    else:
        d[i]+=1;
#print(d)
d_v=list(d.values()) # count of the number of attacks
d_k=list(d.keys()) # in which country
max_attacks=max(d_v)
dan_country=d_k[d_v.index(max_attacks)] # dangerous country
print(f"most dangerous country--> '{dan_country}' with the maximum number of attacks --> {max_attacks}")
# Out:
# most dangerous country--> 'Iraq' with the maximum number of attacks --> 24636

# %%
# country with the maximum number of terror attacks occured in which year?
# Let's consider the data for that particular country
b=df[df.Country==dan_country]
l=list(b.Year)
d={} # key --> Year value--> count
for i in l:
    if i not in d.keys():
        d[i]=1; 
    else:
        d[i]+=1;
print(d)
d_v=list(d.values()) # count of the number of attacks
d_k=list(d.keys()) # in which year
max_attacks=max(d_v)
year=d_k[d_v.index(max_attacks)] # dangerous country
print(f"most dangerous country--> '{dan_country}' with the maximum number of terror attacks --> {max_attacks} in year {year}")
# Out:
# {1975: 1, 1976: 3, 1979: 2, 1980: 6, 1981: 3, 1982: 5, 1983: 3, 1984: 2, 1987: 3, 1988: 4, 1989: 4, 1991: 3, 1992: 35, 1994: 18, 1995: 17, 1996: 12, 1997: 21, 1998: 7, 1999: 12, 2000: 10, 2001: 3, 2002: 6, 2003: 102, 2004: 323, 2005: 617, 2006: 838, 2007: 1047, 2008: 1106, 2009: 1137, 2010: 1179, 2011: 1308, 2012: 1437, 2013: 2852, 2014: 3933, 2015: 2751, 2016: 3360, 2017: 2466}
# most dangerous country--> 'Iraq' with the maximum number of terror attacks --> 3933 in year 2014

# %%
# Find deadliest attack(maximum number of people killed), which Country, Terrorist_Group ?

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# City             434
# Latitude        4556
# Longitude       4557
# AttackType         0
# Killed         10313
# Wounded        16311
# Target           636
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %%
a=df.dropna() # This will remove the rows with NaN entries because here it is the best consideration to ignore data which is not known
a.reset_index(drop=True,inplace=True)
l=list(a.Country)
d={} # key --> Country || value--> count of no. of people killed
for i in l:
    if i not in d.keys():
        c=a[a.Country==i] # this will create the data for that country
        cnt=c.Killed.count()
        d[i]=cnt; 
print(d)
d_v=list(d.values()) # count of the number of people killed
d_k=list(d.keys()) # in which country
max_killed=max(d_v)
country=d_k[d_v.index(max_killed)] # dangerous country
print(f" country--> '{country}' with the maximum number of people killed --> {max_killed}")
# Out:
# {'United States': 1715, 'Poland': 8, 'United Kingdom': 1210, 'Italy': 133, 'France': 497, 'Switzerland': 21, 'Israel': 1137, 'Austria': 24, 'Belgium': 33, 'Brunei': 5, 'Zaire': 3, 'Argentina': 29, "People's Republic of the Congo": 1, 'Jordan': 46, 'Cambodia': 31, 'Australia': 52, 'Portugal': 3, 'India': 8683, 'Sri Lanka': 870, 'Netherlands': 28, 'Nigeria': 2795, 'Guyana': 11, 'Sweden': 85, 'Bangladesh': 1058, 'New Zealand': 12, 'Lebanon': 618, 'Spain': 480, 'Maldives': 20, 'Canada': 58, 'Philippines': 4771, 'Azerbaijan': 18, 'Algeria': 1430, 'South Africa': 148, 'Turkey': 1857, 'Germany': 220, 'Uganda': 177, 'Ethiopia': 87, 'Malta': 6, 'Burundi': 359, 'Russia': 1869, 'Iraq': 23023, 'West Bank and Gaza Strip': 1284, 'Rwanda': 39, 'Greece': 596, 'Pakistan': 12206, 'Bulgaria': 20, 'Thailand': 3335, 'Japan': 44, 'Slovak Republic': 5, 'Chad': 52, 'Colombia': 2121, 'Georgia': 127, 'Peru': 75, 'Sierra Leone': 26, 'Angola': 92, 'Yugoslavia': 94, 'Chile': 95, 'Hungary': 9, 'Egypt': 1946, 'Ire
# ...

# %%
b=a[a.Country==country]
l=list(b.AttackType)
d={} # key --> AttackType || value--> count of this AttackType
for i in l:
    if i not in d.keys():
        d[i]=1
    else:
        d[i]+=1
print(d)
d_v=list(d.values()) # count of the number of people killed
d_k=list(d.keys()) # in which country
max_times=max(d_v)
Attacktype=d_k[d_v.index(max_times)] # dangerous country
print(f" country--> '{country}' with the maximum attack  by --> {Attacktype}  {max_times}times")
c=b[b.AttackType==Attacktype]
cnt=c.Killed.sum()
print(f"and in that total number of people killed are {cnt}")
# Out:
# {'Bombing/Explosion': 17622, 'Assassination': 1219, 'Hostage Taking (Kidnapping)': 484, 'Armed Assault': 2940, 'Unknown': 590, 'Facility/Infrastructure Attack': 135, 'Hijacking': 8, 'Unarmed Assault': 5, 'Hostage Taking (Barricade Incident)': 20}
#  country--> 'Iraq' with the maximum attack  by --> Bombing/Explosion  17622times
# and in that total number of people killed are 49613.0

# %% [markdown]
# # Filtering the data by applying multiple condition using loc

# %%
# Total number of attacks done after 14 May,2014

# %%
a=a.loc[((a['Year']==2014) & (a['Month']==5) & (a['Day']>=14) & (a['Country']=='India')) | ((a['Year']>=2014) & (a['Month']>=6) & (a['Country']=='India'))]
a
# Out:
#         Year  Month  Day Country              State      Region  \
# 61030   2014      5   14   India            Manipur  South Asia
# 61031   2014      5   14   India            Manipur  South Asia
# 61035   2014      5   14   India             Odisha  South Asia
# 61037   2014      5   14   India            Manipur  South Asia
# 61039   2014      5   14   India       Chhattisgarh  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 105546  2017     12   30   India             Kerala  South Asia
# 105548  2017     12   30   India       Chhattisgarh  South Asia
# 105553  2017     12   31   India  Jammu and Kashmir  South Asia
# 105565  2017     12   31   India              Assam  South Asia
# 105570  2017     12   31   India            Manipur  South Asia
#
#                        City   Latitude  Longitude  \
# 61030                Imphal  24.798346  93.940430
# 61031                Imphal  24.798346  93.940430
# ...

# %%
l=list(a.AttackType)
d={} # key --> AttackType || value--> count of this AttackType
for i in l:
    if i not in d.keys():
        d[i]=1
    else:
        d[i]+=1
print(d)
d_v=list(d.values()) # count of the number of people killed
d_k=list(d.keys()) # in which country
max_times=max(d_v)
Attacktype=d_k[d_v.index(max_times)] # dangerous country
print(f" country--> 'India' with the maximum attack  by --> {Attacktype}  {max_times}times")
c=a[a.AttackType==Attacktype]
cnt=c.Killed.sum()
print(f"and in that total number of people killed are {cnt}")
# Out:
# {'Bombing/Explosion': 838, 'Armed Assault': 466, 'Facility/Infrastructure Attack': 278, 'Hostage Taking (Kidnapping)': 230, 'Assassination': 103, 'Unknown': 43, 'Unarmed Assault': 36, 'Hostage Taking (Barricade Incident)': 14, 'Hijacking': 3}
#  country--> 'India' with the maximum attack  by --> Bombing/Explosion  838times
# and in that total number of people killed are 157.0

# %%
a[a.AttackType==Attacktype].Killed.sum()
# Out:
# 157.0
